# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/atlantico-academy/datasets/main/titanic.csv')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.to_csv('../data/raw/data.csv', index=False)

# %%
dicionario = pd.DataFrame([
    {
        "variavel": "survived",
        "descricao": "Sobreviventes ou não do passageiro",
        "tipo":"quantitativa",
        "subtipo":"discreta"
    },{
        "variavel": "pclass",
        "descricao": "Número da classe do passageiro",
        "tipo":"quantitativa",
        "subtipo":"discreta"
    },{
        "variavel": "sex",
        "descricao": "Sexo do passageiro",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "age",
        "descricao": "Idade do passageiro",
        "tipo":"quantitativa",
        "subtipo":"discreta"
    },{
        "variavel": "sibsp",
        "descricao": "Quantidade de irmãos/cônjuges a bordo",
        "tipo":"quantitativa",
        "subtipo":"discreta"
    },{
        "variavel": "parch",
        "descricao": "Quantidade de pais / crianças a bordo",
        "tipo":"quantitativa",
        "subtipo":"discreta"
    },{
        "variavel": "fare",
        "descricao": "Tarifa paga pelo passageiro",
        "tipo":"quantitativa",
        "subtipo":"discreta"
    },{
        "variavel": "embarked",
        "descricao": "Sigla do porto de Embarque",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "class",
        "descricao": "Nome da classe do passageiro",
        "tipo":"qualitativa",
        "subtipo":"ordinal"
    },{
        "variavel": "who",
        "descricao": "Classificação do passageiro",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "adult_male",
        "descricao": "Se é ou não um homem adulto",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "deck",
        "descricao": "Andar do passageiro",
        "tipo":"qualitativa",
        "subtipo":"ordinal"
    },{
        "variavel": "embark_town",
        "descricao": "Nome do porto de embarque",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "alive",
        "descricao": "Sobrevivente ou não",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "alone",
        "descricao": "Sozinho ou não",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    }
])
dicionario.to_csv('../data/external/dictionary.csv', index=False)
dicionario
# Out:
#        variavel                              descricao          tipo   subtipo
# 0      survived     Sobreviventes ou não do passageiro  quantitativa  discreta
# 1        pclass         Número da classe do passageiro  quantitativa  discreta
# 2           sex                     Sexo do passageiro   qualitativa   nominal
# 3           age                    Idade do passageiro  quantitativa  discreta
# 4         sibsp  Quantidade de irmãos/cônjuges a bordo  quantitativa  discreta
# 5         parch  Quantidade de pais / crianças a bordo  quantitativa  discreta
# 6          fare            Tarifa paga pelo passageiro  quantitativa  discreta
# 7      embarked             Sigla do porto de Embarque   qualitativa   nominal
# 8         class           Nome da classe do passageiro   qualitativa   ordinal
# 9           who            Classificação do passageiro   qualitativa   nominal
# 10   adult_male            Se é ou não um homem adulto   qualitativa   nominal
# ...
